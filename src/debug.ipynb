# %%
from ebm.train import train
config = {
    'dataset': '3d-circles',  # Dataset name
    'epochs': 300,  # Number of epochs
    'input_size': 3,  # 3D input
    'hidden_sizes': [128, 2],  # Hidden layer sizes
    'beta': 0.2,  # Temperature parameter
    'dt': 0.05,   # Step size
    'n_steps': 20, # Number of steps
    'verbose': False
}

model, history = train(config)
# Out:
# Training Epoch: 100%|██████████| 300/300 [01:05<00:00,  4.59it/s]
