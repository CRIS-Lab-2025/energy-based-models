# %%
MODEL_PATH = "ebm_full.pt"  # Will save in /content by default in Colab
from multi_layer import EnergyBasedModel
import torch
# try:
    
#     model = EnergyBasedModel.load_from_file(MODEL_PATH)
#     print("Loaded pretrained model from local disk.")

# except Exception as e:
# print(f"Could not load model: {e}")
# print("Training a new model...")

model = EnergyBasedModel.train_model(
    subset_size=10000,
    epochs=200,
    lr = 0.6,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.8,
)

# model.save_to_file(MODEL_PATH)
print(f"Model trained and saved locally at: {MODEL_PATH}")

# %%
MODEL_PATH = "ebm_full.pt"  # Will save in /content by default in Colab
from multi_layer import EnergyBasedModel
import torch
# try:
    
#     model = EnergyBasedModel.load_from_file(MODEL_PATH)
#     print("Loaded pretrained model from local disk.")

# except Exception as e:
# print(f"Could not load model: {e}")
# print("Training a new model...")

model = EnergyBasedModel.train_model(
    subset_size=10000,
    epochs=100,
    lr = 0.6,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.8,
)

# model.save_to_file(MODEL_PATH)
print(f"Model trained and saved locally at: {MODEL_PATH}")
# Out:
# Model trained and saved locally at: ebm_full.pt

# %%
MODEL_PATH = "ebm_full.pt"  # Will save in /content by default in Colab
from multi_layer import EnergyBasedModel
import torch
# try:
    
#     model = EnergyBasedModel.load_from_file(MODEL_PATH)
#     print("Loaded pretrained model from local disk.")

# except Exception as e:
# print(f"Could not load model: {e}")
# print("Training a new model...")

model = EnergyBasedModel.train_model(
    subset_size=10000,
    epochs=100,
    lr = 0.3,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.4,
)

# model.save_to_file(MODEL_PATH)
print(f"Model trained and saved locally at: {MODEL_PATH}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_26978/1104703585.py in <module>
#      11 # print("Training a new model...")
#      12
# ---> 13 model = EnergyBasedModel.train_model(
#      14     subset_size=10000,
#      15     epochs=100,
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in train_model(cls, **kwargs)
#     223     def train_model(cls, **kwargs):
#     224         model = cls(**kwargs)
# --> 225         model.train()
#     226         return model
#     227
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in train(self, cutoff_accuracy)
#     255                 s0 = torch.rand(xb.shape[0], self.num_state_units, device=self.device) * 0.1
#     256
# --> 257                 s_free, u_free = self.run_free_phase(s0, xb)
#     258                 s_nudge, u_nudge = self.run_nudged_phase(s_free, xb, yb)
#     259
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in run_free_phase(self, s0, x)
#     200
#     201     def run_free_phase(self, s0, x):
# --> 202         return self.simulate(s0, x, beta=0, y_target=None, n_iter=self.n_free)
#     203
#     204     def run_nudged_phase(self, s_free, x, y_target):
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in simulate(self, s_init, x, beta, y_target, n_iter, learn_input, stochastic)
#     171             rho_prime = hard_sigmoid_deriv(s.detach() if learn_input else s)
#     172
# --> 173             grad_s = self.energy_grad(s, rho_u.detach(), rho_prime, y_target)
#     174
#     175             # --- Stochastic MCMC-style Langevin step ---
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in energy_grad(self, s, rho_u, rho_prime, y_target, h_target)
#     107         # in → hidden  (W[idx_in, idx_h] = W_ih)
#     108         for i in range(1,self.n_layers-1):
# --> 109             out[:, self.idx[i]]    = rho_u[:, self.idx[i-1]]   @ self.W[i-1] + rho_u[:, self.idx[i+1]]  @ self.W[i].T
#     110
#     111         # hidden → in   (W[idx_h, idx_in] = W_ih.T)
#
# KeyboardInterrupt:

# %%
MODEL_PATH = "ebm_full.pt"  # Will save in /content by default in Colab
from multi_layer import EnergyBasedModel
import torch
# try:
    
#     model = EnergyBasedModel.load_from_file(MODEL_PATH)
#     print("Loaded pretrained model from local disk.")

# except Exception as e:
# print(f"Could not load model: {e}")
# print("Training a new model...")

model = EnergyBasedModel.train_model(
    subset_size=10000,
    epochs=100,
    lr = 0.3,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.2,
)

# model.save_to_file(MODEL_PATH)
print(f"Model trained and saved locally at: {MODEL_PATH}")
# Out:
# tensor([0.3737, 0.3249, 0.3291, 0.2832, 0.3382, 0.3846, 0.3669, 0.3271, 0.3315,
#         0.2844, 0.3201, 0.2986, 0.3349, 0.3243, 0.3743, 0.3291, 0.2985, 0.2890,
#         0.3424, 0.3484, 0.2976, 0.3213, 0.3201, 0.3307, 0.3731, 0.3345, 0.3315,
#         0.3537, 0.3273, 0.3242, 0.3214, 0.2830, 0.3349, 0.3270, 0.3251, 0.3286,
#         0.4267, 0.2667, 0.2980, 0.6258, 0.4287, 0.5324, 0.3345, 0.2664, 0.3157,
#         0.3053, 0.3227, 0.3246, 0.3363, 0.2862, 0.3089, 0.0212, 0.2556, 0.2222,
#         0.0777, 0.0078, 0.3225, 0.5120, 0.5481, 0.0419, 0.0034, 0.0114, 0.4978,
#         0.1406, 0.0810, 0.1043, 0.0203, 0.0147, 0.0705, 0.0469, 0.0348, 0.0116,
#         0.0949, 0.0052])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_26978/96130657.py in <module>
#      11 # print("Training a new model...")
#      12
# ---> 13 model = EnergyBasedModel.train_model(
#      14     subset_size=10000,
#      15     epochs=100,
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in train_model(cls, **kwargs)
#     223     def train_model(cls, **kwargs):
#     224         model = cls(**kwargs)
# --> 225         model.train()
#     226         return model
#     227
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in train(self, cutoff_accuracy)
#     281             b[idx_s] += self.lr_b * db / (self.subset_size // self.batch_size)
#     282
# --> 283             acc = self.evaluate(X_test, y_test, n_iter=self.n_free)
#     284             print(f"Epoch {epoch+1:3d} | Loss: {total_loss/self.subset_size:.6f} | Acc: {acc:.4f}")
#     285
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in evaluate(self, X, y_true, n_iter)
#     211                 xb = X[i:i+512]
#     212                 s0 = torch.rand(xb.shape[0], self.num_state_units, device=self.device) * 0.1
# --> 213                 s_out, _ = self.simulate(s0, xb, beta=0, y_target=None, n_iter=n_iter)
#     214                 preds.append(torch.argmax(s_out[:, self.idx_s_out], dim=1))
#     215
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in simulate(self, s_init, x, beta, y_target, n_iter, learn_input, stochastic)
#     181                 s_new = s_new * (1 - self.clamp_mask[self.idx_s]) + self.clamp_values[self.idx_s] * self.clamp_mask[self.idx_s]
#     182             # Do batch normalization
# --> 183             idx_s_hid = torch.tensor(np.where(np.isin(self.idx_s.cpu(), self.idx[1].cpu()))[0], device=self.device)
#     184             s_mean = s_new[:, idx_s_hid].mean(0)
#     185             s_std = s_new[:, idx_s_hid].std(0)
#
# ~/.local/lib/python3.10/site-packages/numpy/core/overrides.py in isin(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/numpy/lib/arraysetops.py in isin(element, test_elements, assume_unique, invert, kind)
#     888     """
#     889     element = np.asarray(element)
# --> 890     return in1d(element, test_elements, assume_unique=assume_unique,
#     891                 invert=invert, kind=kind).reshape(element.shape)
#     892
#
# ~/.local/lib/python3.10/site-packages/numpy/core/overrides.py in in1d(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/numpy/lib/arraysetops.py in in1d(ar1, ar2, assume_unique, invert, kind)
#     644             ar2 = ar2.astype(np.uint8)
#     645
# --> 646         ar2_min = np.min(ar2)
#     647         ar2_max = np.max(ar2)
#     648
#
# ~/.local/lib/python3.10/site-packages/numpy/core/overrides.py in amin(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py in _amin_dispatcher(a, axis, out, keepdims, initial, where)
#    2822
#    2823
# -> 2824 def _amin_dispatcher(a, axis=None, out=None, keepdims=None, initial=None,
#    2825                      where=None):
#    2826     return (a, out)
#
# KeyboardInterrupt:

# %%
MODEL_PATH = "ebm_full.pt"  # Will save in /content by default in Colab
from multi_layer import EnergyBasedModel
import torch
# try:
    
#     model = EnergyBasedModel.load_from_file(MODEL_PATH)
#     print("Loaded pretrained model from local disk.")

# except Exception as e:
# print(f"Could not load model: {e}")
# print("Training a new model...")

model = EnergyBasedModel.train_model(
    subset_size=10000,
    epochs=100,
    lr = 0.3,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.2,
)

# model.save_to_file(MODEL_PATH)
print(f"Model trained and saved locally at: {MODEL_PATH}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_25757/96130657.py in <module>
#      11 # print("Training a new model...")
#      12
# ---> 13 model = EnergyBasedModel.train_model(
#      14     subset_size=10000,
#      15     epochs=100,
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in train_model(cls, **kwargs)
#     222     def train_model(cls, **kwargs):
#     223         model = cls(**kwargs)
# --> 224         model.train()
#     225         return model
#     226
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in train(self, cutoff_accuracy)
#     270                 total_loss += loss.item() * xb.shape[0]
#     271
# --> 272                 total_free_E += self.compute_energy(s_free, u_free).mean().item()
#     273                 total_nudge_E += self.compute_energy(s_nudge, u_nudge).mean().item()
#     274
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in compute_energy(self, s, u)
#      99         # Compute energy contributions from all layer connections
#     100         for i in range(self.n_layers-1):
# --> 101             term3 += torch.sum((rho_u[:, self.idx[i]] @ self.W[i]) * rho_u[:, self.idx[i+1]], dim=1)
#     102         term3 = -0.5 * term3
#     103         return term1 + term2 + term3
#
# KeyboardInterrupt:

# %%
MODEL_PATH = "ebm_full.pt"  # Will save in /content by default in Colab
from multi_layer import EnergyBasedModel
import torch
# try:
    
#     model = EnergyBasedModel.load_from_file(MODEL_PATH)
#     print("Loaded pretrained model from local disk.")

# except Exception as e:
# print(f"Could not load model: {e}")
# print("Training a new model...")

model = EnergyBasedModel.train_model(
    subset_size=10000,
    epochs=100,
    lr = 0.2,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.2,
)

# model.save_to_file(MODEL_PATH)
print(f"Model trained and saved locally at: {MODEL_PATH}")
# Out:
# tensor([0.3423, 0.3381, 0.3239, 0.3186, 0.3461, 0.3551, 0.3148, 0.3118, 0.3207,
#         0.3068, 0.3054, 0.2977, 0.2938, 0.3043, 0.2958, 0.2969, 0.3207, 0.3226,
#         0.2940, 0.3285, 0.3036, 0.3183, 0.3012, 0.3534, 0.3123, 0.3009, 0.2933,
#         0.3217, 0.3057, 0.3593, 0.2989, 0.3027, 0.3174, 0.2946, 0.3101, 0.3189,
#         0.2938, 0.3115, 0.3116, 0.2944, 0.2965, 0.3129, 0.3369, 0.4218, 0.3113,
#         0.3728, 0.3840, 0.2883, 0.3719, 0.2908, 0.2884, 0.2932, 0.2950, 0.2822,
#         0.3606, 0.4388, 0.4492, 0.3591, 0.2945, 0.3426, 0.2963, 0.2940, 0.2905,
#         0.3120, 0.3014, 0.3221, 0.3754, 0.3173, 0.2973, 0.3154, 0.3681, 0.3077,
#         0.3038, 0.3166])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_25757/564561630.py in <module>
#      11 # print("Training a new model...")
#      12
# ---> 13 model = EnergyBasedModel.train_model(
#      14     subset_size=10000,
#      15     epochs=100,
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in train_model(cls, **kwargs)
#     222     def train_model(cls, **kwargs):
#     223         model = cls(**kwargs)
# --> 224         model.train()
#     225         return model
#     226
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in train(self, cutoff_accuracy)
#     280             b[idx_s] += self.lr_b * db / (self.subset_size // self.batch_size)
#     281
# --> 282             acc = self.evaluate(X_test, y_test, n_iter=self.n_free)
#     283             print(f"Epoch {epoch+1:3d} | Loss: {total_loss/self.subset_size:.6f} | Acc: {acc:.4f}")
#     284
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in evaluate(self, X, y_true, n_iter)
#     210                 xb = X[i:i+512]
#     211                 s0 = torch.rand(xb.shape[0], self.num_state_units, device=self.device) * 0.1
# --> 212                 s_out, _ = self.simulate(s0, xb, beta=0, y_target=None, n_iter=n_iter)
#     213                 preds.append(torch.argmax(s_out[:, self.idx_s_out], dim=1))
#     214
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in simulate(self, s_init, x, beta, y_target, n_iter, learn_input, stochastic)
#     184             s_std = s_new.std(0)
#     185             s_new = (s_new - s_mean) / (s_std + 1e-8) #* 0.1 + s_mean
# --> 186             s = torch.clamp(s_new, 0, 1).detach()
#     187
#     188             # Optional input learning via energy minimization
#
# KeyboardInterrupt:

# %%
MODEL_PATH = "ebm_full.pt"  # Will save in /content by default in Colab
from multi_layer import EnergyBasedModel
import torch
# try:
    
#     model = EnergyBasedModel.load_from_file(MODEL_PATH)
#     print("Loaded pretrained model from local disk.")

# except Exception as e:
# print(f"Could not load model: {e}")
# print("Training a new model...")

model = EnergyBasedModel.train_model(
    subset_size=10000,
    epochs=100,
    lr = 0.6,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.2,
)

# model.save_to_file(MODEL_PATH)
print(f"Model trained and saved locally at: {MODEL_PATH}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_25757/3237131191.py in <module>
#      11 # print("Training a new model...")
#      12
# ---> 13 model = EnergyBasedModel.train_model(
#      14     subset_size=10000,
#      15     epochs=100,
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in train_model(cls, **kwargs)
#     222     def train_model(cls, **kwargs):
#     223         model = cls(**kwargs)
# --> 224         model.train()
#     225         return model
#     226
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in train(self, cutoff_accuracy)
#     254                 s0 = torch.rand(xb.shape[0], self.num_state_units, device=self.device) * 0.1
#     255
# --> 256                 s_free, u_free = self.run_free_phase(s0, xb)
#     257                 s_nudge, u_nudge = self.run_nudged_phase(s_free, xb, yb)
#     258
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in run_free_phase(self, s0, x)
#     199
#     200     def run_free_phase(self, s0, x):
# --> 201         return self.simulate(s0, x, beta=0, y_target=None, n_iter=self.n_free)
#     202
#     203     def run_nudged_phase(self, s_free, x, y_target):
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in simulate(self, s_init, x, beta, y_target, n_iter, learn_input, stochastic)
#     169
#     170             rho_u = hard_sigmoid(u)
# --> 171             rho_prime = hard_sigmoid_deriv(s.detach() if learn_input else s)
#     172
#     173             grad_s = self.energy_grad(s, rho_u.detach(), rho_prime, y_target)
#
# ~/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py in hard_sigmoid_deriv(x)
#      17 # --- Activations ---
#      18 def hard_sigmoid(x): return torch.clamp(x, 0, 1)
# ---> 19 def hard_sigmoid_deriv(x): return ((x >= 0) & (x <= 1)).float()
#      20
#      21 # --- Dataset ---
#
# KeyboardInterrupt:

# %%
MODEL_PATH = "ebm_full.pt"  # Will save in /content by default in Colab
from multi_layer import EnergyBasedModel
import torch
# try:
    
#     model = EnergyBasedModel.load_from_file(MODEL_PATH)
#     print("Loaded pretrained model from local disk.")

# except Exception as e:
# print(f"Could not load model: {e}")
# print("Training a new model...")

model = EnergyBasedModel.train_model(
    subset_size=10000,
    epochs=100,
    lr = 0.05,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.8,
)

# model.save_to_file(MODEL_PATH)
print(f"Model trained and saved locally at: {MODEL_PATH}")
# Out:
# Model trained and saved locally at: ebm_full.pt

# %%
MODEL_PATH = "ebm_full.pt"  # Will save in /content by default in Colab
from multi_layer import EnergyBasedModel
import torch
# try:
    
#     model = EnergyBasedModel.load_from_file(MODEL_PATH)
#     print("Loaded pretrained model from local disk.")

# except Exception as e:
# print(f"Could not load model: {e}")
# print("Training a new model...")

model = EnergyBasedModel.train_model(
    subset_size=10000,
    epochs=100,
    lr_ih=0.6,
    lr_ho=0.6,
    lr_b=0.6,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.8,
)

# model.save_to_file(MODEL_PATH)
print(f"Model trained and saved locally at: {MODEL_PATH}")
# Out:
# Model trained and saved locally at: ebm_full.pt

# %%
# Check if the model object exists and inspect its properties
if 'model' in locals() or 'model' in globals():
    print(f"Model exists, type: {type(model)}")
    print(f"Model architecture: {model.weights if hasattr(model, 'weights') else 'Architecture info not available'}")
    print(f"Free energy iterations: {model.n_free}")
    print(f"Device: {model.device}")
else:
    print("Model variable not found. Check previous cell execution.")
    
# Inspect the data
print(f"\nTest data shape: {X_test.shape}")
print(f"Test labels shape: {y_test.shape}")
print(f"First 5 test labels: {y_test[:5]}")

# %%
from multi_layer import EnergyBasedModel
from model import load_mnist
import torch

MODEL_PATH = "ebm_full.pt"  # Will save in /content by default in Colab

# Load test set for final evaluation
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
(_, _, _), (X_test, y_test_1hot, y_test) = load_mnist()
X_test = torch.tensor(X_test).to(device)
y_test = torch.tensor(y_test).to(device)

try:
    raise FileNotFoundError  # Uncomment this line to force training a new model
    print("Loaded pretrained model from local disk.")

except Exception as e:
    print(f"Could not load model: {e}")
    print("Training a new model...")

    model = EnergyBasedModel.train_model(
        subset_size=10000,
        epochs=100,
        hidden_dim=64,
        lr_ih=0.6,
        lr_ho=0.6,
        lr_b=0.6,
        n_free=20,
        n_nudge=2,
        dt=1,
        beta=0.8,
    )

    #model.save_to_file(MODEL_PATH)
    print(f"Model trained and saved locally at: {MODEL_PATH}")


# Always evaluate
acc = model.evaluate(X_test, y_test, n_iter=model.n_free)
print(f"Test Accuracy: {acc:.2%}")
print()
# Out:
# Model trained and saved locally at: ebm_full.pt
# Test Accuracy: 90.55%
# /home/likhith/Documents/energy-based-models/sadie_multi_layer_ebm/multi_layer.py:204: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_true_t = torch.tensor(y_true[:len(preds)], device=self.device)

# %%
from model import EnergyBasedModel
from model import load_mnist
import torch

MODEL_PATH = "ebm_full.pt"  # Will save in /content by default in Colab

# Load test set for final evaluation
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
(_, _, _), (X_test, y_test_1hot, y_test) = load_mnist()
X_test = torch.tensor(X_test).to(device)
y_test = torch.tensor(y_test).to(device)

try:
    model = EnergyBasedModel.load_from_file(MODEL_PATH)
    print("Loaded pretrained model from local disk.")

except Exception as e:
    print(f"Could not load model: {e}")
    print("Training a new model...")

    model = EnergyBasedModel.train_model(
        subset_size=10000,
        epochs=100,
        hidden_dim=64,
        lr_ih=0.6,
        lr_ho=0.6,
        lr_b=0.6,
        n_free=20,
        n_nudge=2,
        dt=1,
        beta=0.8,
    )

    model.save_to_file(MODEL_PATH)
    print(f"Model trained and saved locally at: {MODEL_PATH}")


# Always evaluate
acc = model.evaluate(X_test, y_test, n_iter=model.n_free)
print(f"Test Accuracy: {acc:.2%}")
print()
# Out:
# EBM saved to ebm_full.pt
# Model trained and saved locally at: ebm_full.pt
# Test Accuracy: 88.71%
# /home/likhith/Documents/energy-based-models/sadie_multi_layer_ebm/model.py:193: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_true_t = torch.tensor(y_true[:len(preds)], device=self.device)
