# %%
from multi_layer import EnergyBasedModel
model = EnergyBasedModel.train_model(
    model = [784,256,64,10],
    subset_size=10000,
    epochs=20,
    lr = 0.3,
    n_free=100,
    n_nudge=10,
    dt=0.5,
    beta=0.7,
)

# %%
from sparse_energy import SparseEnergy

model = SparseEnergy.train_model(
    model = [784,256,64,10],
    subset_size=10000,
    epochs=20,
    lr = 0.3,
    n_free=100,
    n_nudge=10,
    dt=0.5,
    beta=0.7,
)

# %%
from multi_layer import EnergyBasedModel
model = EnergyBasedModel.train_model(
    model = [784,64,256,10],
    subset_size=10000,
    epochs=20,
    lr = 0.3,
    n_free=100,
    n_nudge=10,
    dt=0.5,
    beta=0.7,
)

# %%
from sparse_energy import SparseEnergy

model = SparseEnergy.train_model(
    model = [784,64,32,10],
    subset_size=10000,
    epochs=20,
    lr = 0.6,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.8,
)

# %%
from multi_layer import EnergyBasedModel
model = EnergyBasedModel.train_model(
    model = [784,32,32,10],
    subset_size=10000,
    epochs=20,
    lr = 0.6,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.8,
)

# %%
from sparse_energy import SparseEnergy

model = SparseEnergy.train_model(
    model = [784,32,32,10],
    subset_size=10000,
    epochs=20,
    lr = 0.6,
    n_free=20,
    n_nudge=2,
    dt=1,
    beta=0.8,
)
